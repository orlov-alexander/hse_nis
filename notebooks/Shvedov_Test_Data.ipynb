# %%
import pandas as pd
import numpy as np
import sqlite3
import datetime
import sklearn
import sqlalchemy as sa

# %%
from sklearn.model_selection import TimeSeriesSplit

import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, auc

import operator

# %%
# !ls ../
# Out:
# HSE_final_presentation.pdf  data  notebooks

# %%
# создание коннекта к БД и крурсора для запросов
conn = sqlite3.connect('../data/input/user_info_HSE_hashed.sqlite')
c = conn.cursor()

# %%
# пример получения перечня таблиц (в данном случае она будет 1)
c.execute("SELECT name FROM sqlite_master WHERE type='table';")
print ('Перечень таблиц: {0}\r\n\r\n'.format(c.fetchall()))

# перечень столбцов
c.execute("SELECT * FROM rsa_event_log LIMIT 1;")
cols = [descr[0] for descr in c.description]
print ('Столбцы в таблице: {0}'.format(cols))
# Out:
# Перечень таблиц: [('rsa_event_log',)]
#
#
# Столбцы в таблице: ['cdf_s_123', 'cdf_s_124', 'cdf_s_127', 'cdf_s_135', 'cdf_s_130', 'cdf_s_129', 'cdf_s_134', 'cdf_s_128', 'cdf_s_138', 'cdf_s_126', 'cdf_s_133', 'cdf_s_136', 'cdf_s_137', 'cdf_s_140', 'cdf_s_178_hashed', 'cdf_s_19', 'cdf_s_20', 'cdf_s_218', 'cdf_s_294', 'cdf_s_299', 'amount_original', 'channel_indicator_desc', 'data_i_118', 'data_i_119', 'data_i_120', 'data_i_154', 'data_s_65', 'event_description', 'event_id', 'event_time', 'ext_acct_number_hashed', 'hardwareid', 'short_date', 'user_acct_number_hashed', 'user_agent_string_hash', 'browser_plugins_hash', 'screen_hash', 'user_id', 'ip_address', 'ip_country', 'ip_region', 'ip_city', 'ip_isp']

# %%
# Пример форомирования DataFrame из БД с заполнением типа полей

def transform_cols (df, dict_col_types = None):
    # Расширяйте для необходимых столбцов и их явной типизации
    if dict_col_types is None:
        dict_col_types = {
        'amount_original':(float, 0.0),
        'cdf_s_126':(str, u'null'),
        'cdf_s_138':(str, u'null'),
        'channel_indicator':(str, u'null'),
        'event_description':(str, u'null'),
        'cdf_s_294':(int, 0),
        'cdf_s_140':(float, 0.0),
        'data_i_120':(int, 0),
        'cdf_s_218':(str, u'null'),
        'data_s_65':(int, 0),
        'cdf_s_127':(int, 30),
        'cdf_s_135':(int, 30),
        'cdf_s_130':(int, 30),
        'cdf_s_129':(int, 30),
        'cdf_s_134':(int, 30),
        'data_i_154':(float, np.nan),
        'cdf_s_133':(int, 30),
        'cdf_s_20':(str, u'null'),
        'cdf_s_299':(str, u'null'),
        }
                
    if df.shape[0] > 0:
        df.replace(u'null', np.nan, inplace=True)

        for i in dict_col_types:
            if i in df.columns:
                df[i] = df[i].fillna(dict_col_types[i][1]).astype(dict_col_types[i][0])
    
    return df
    

def df_from_sql (sql, parse_dates = ['event_time','cdf_s_19', 'cdf_s_123','cdf_s_124'], dict_col_types = None, chunk_size = None, engine=engine):
    """
    Функция вощвращающая df в результате переданного sql-запроса
    Также поддерживается приведение столбцов к заданным типам 
    и чтение по блокам
    """
     
    if chunk_size is not None:
        df_iter =  [transform_cols(chunk, dict_col_types) for chunk in pd.read_sql_query(sql, engine, parse_dates = parse_dates, chunksize=chunk_size)]
    else:
        df_iter = transform_cols(pd.read_sql_query(sql, engine, parse_dates = parse_dates), dict_col_types)
        #df_iter = pd.read_sql_query(sql, engine, con=conn,  parse_dates = parse_dates)
    
    return df_iter

# %%
# создание индексов для ускорения поиска
# описанные здесь уже созданы в предоставленной БД, при необходимотси можете расширить набор
cols_to_index = ['user_id', 'short_date',  'channel_indicator_desc', 'event_description']

for col in cols_to_index:
    c.execute('CREATE INDEX {ix} on {tn}({cn})'\
            .format(ix='indx_new_{0}'.format(col), tn='rsa_event_log', cn=col)) # add new index indx_new_{0}

c.execute('CREATE INDEX date_user_event on rsa_event_log(short_date, user_id, event_description);')   
    
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-104-0758a8e9837a> in <module>()
#       4
#       5 for col in cols_to_index:
# ----> 6     c.execute('CREATE INDEX {ix} on {tn}({cn})'            .format(ix='indx_new_{0}'.format(col), tn='rsa_event_log', cn=col)) # add new index indx_new_{0}
#       7
#       8 c.execute('CREATE INDEX date_user_event on rsa_event_log(short_date, user_id, event_description);')
#
# OperationalError: index indx_new_user_id already exists

# %%
#  Общий срез по данным
c.execute("select COUNT(*) from rsa_event_log;")
print ('Общее число транзакций: {0}'.format(c.fetchall()))


# Число уникальных пользователей
c.execute("select COUNT(DISTINCT user_id) from rsa_event_log;")
print ("Уникальных пользователей: {0}".format(c.fetchall()))

# Временной диапазон и количество клиентов
c.execute("select min(short_date), max(short_date) from rsa_event_log;")
print('Диапазон дат: {0}'.format(c.fetchall()))
# Out:
# Общее число транзакций: [(11832149,)]
# Уникальных пользователей: [(85764,)]
# Диапазон дат: [(20171007, 20171205)]

# %%
all_users = df_from_sql('select DISTINCT user_id from rsa_event_log;',
                        engine=conn,
                        parse_dates=None)

# %%
sample_users = all_users.sample(frac=0.05).user_id.astype(str).tolist()

# %%
start_date = 20171129
end_date = 20171205

# %%
data = df_from_sql('select * from rsa_event_log where short_date >= 20171129 and short_date <=  20171205;',engine=conn,
                        parse_dates=None)

# %%
data.to_csv('test_data.csv', sep='\t')
# Out:
# 0          20171129
# 1          20171129
# 2          20171129
# 3          20171129
# 4          20171129
# 5          20171129
# 6          20171129
# 7          20171129
# 8          20171129
# 9          20171129
# 10         20171129
# 11         20171129
# 12         20171129
# 13         20171129
# 14         20171129
# 15         20171129
# 16         20171129
# 17         20171129
# 18         20171129
# 19         20171129
# 20         20171129
# 21         20171129
# 22         20171129
# 23         20171129
# 24         20171129
# 25         20171129
# 26         20171129
# 27         20171129
# 28         20171129
# 29         20171129
#              ...
# 1996443    20171205
# 1996444    20171205
# 1996445    20171205
# 1996446    20171205
# 1996447    20171205
# 1996448    20171205
# 1996449    20171205
# 1996450    20171205
# 1996451    20171205
# 1996452    20171205
# 1996453    20171205
# 1996454    20171205
# 1996455    20171205
# 1996456    20171205
# 1996457    20171205
# 1996458    20171205
# 1996459    20171205
# 1996460    20171205
# 1996461    20171205
# 1996462    20171205
# 1996463    20171205
# 1996464    20171205
# 1996465    20171205
# 1996466    20171205
# 1996467    20171205
# 1996468    20171205
# 1996469    20171205
# 1996470    20171205
# 1996471    20171205
# 1996472    20171205
# Name: short_date, Length: 1996473, dtype: int64

# %%
data.to_csv('test_data.csv', sep=',')

# %%
data
# Out:
#                      cdf_s_123              cdf_s_124  cdf_s_127  cdf_s_135  \
# 0                         None                   None         30         30
# 1                         None                   None         30         30
# 2                         None                   None         30         30
# 3                         None                   None         30         30
# 4                         None                   None         30         30
# 5                         None                   None         30         30
# 6                         None                   None         30          2
# 7                         None                   None         30          2
# 8                         None                   None         30         30
# 9                         None                   None         30         30
# 10                        None                   None         30         30
# 11                        None                   None         30         30
# 12                        None                   None         30          2
# 13                        None                   None         30          2
# 14                        None                   None         30         30
# 15                        None                   None         30         30
# 16                        None                   None         30          4
# 17                        None                   None         30          4
# 18       1994-08-21 00:00:00.0  2017-09-12 00:00:00.0         30          0
# 19                        None                   None         30          0
# 20                        None                   None         30          0
# 21                        None                   None         30          0
# 22                        None                   None         30          0
# 23                        None                   None         30          0
# 24                        None                   None         30          0
# 25       1994-07-10 00:00:00.0  2017-03-17 00:00:00.0         30          0
# 26       1987-05-07 00:00:00.0  2016-10-14 00:00:00.0         30          0
# 27       1989-05-14 00:00:00.0  2016-09-17 00:00:00.0         30          0
# 28       1994-10-21 00:00:00.0  2017-08-10 00:00:00.0         30          0
# 29                        None                   None         30          0
# ...                        ...                    ...        ...        ...
# 1996443                   None                   None         30         30
# 1996444  2003-02-19 00:00:00.0  2017-08-31 00:00:00.0         30         30
# 1996445                   None                   None         30          5
# 1996446                   None                   None         30         30
# 1996447                   None                   None         30         30
# 1996448                   None                   None         30         30
# 1996449                   None                   None         30         30
# 1996450                   None                   None         30          0
# 1996451                   None                   None         30          1
# 1996452                   None                   None         30          1
# 1996453                   None                   None         30          1
# 1996454                   None                   None         30         30
# 1996455  2017-05-24 00:00:00.0  1995-01-07 00:00:00.0         30         30
# 1996456                   None                   None         30         30
# 1996457                   None                   None         30         30
# 1996458                   None                   None         30         30
# 1996459                   None                   None         30         30
# 1996460                   None                   None         30          0
# 1996461                   None                   None         30          0
# 1996462                   None                   None         30          1
# 1996463                   None                   None         30          1
# 1996464                   None                   None         30          1
# 1996465                   None                   None         30          1
# 1996466                   None                   None         30          0
# 1996467                   None                   None         30          0
# 1996468                   None                   None         30         30
# 1996469                   None                   None         30         30
# 1996470                   None                   None         30         30
# 1996471                   None                   None         30          5
# 1996472                   None                   None         30         30
#
#          cdf_s_130  cdf_s_129  cdf_s_134  cdf_s_128 cdf_s_138 cdf_s_126  \
# 0               30         30          5        NaN      null      null
# 1               30         30          5        NaN      null      null
# 2               30         30          0        NaN      null      null
# 3               30         30          0        NaN      null      null
# 4               30         30          5        NaN       НЕТ       НЕТ
# 5               30         30          0        NaN       НЕТ        ДА
# 6               30         30          0        NaN       НЕТ        ДА
# 7               30         30          0        NaN       НЕТ        ДА
# 8               30         30          5        NaN      null      null
# 9               30         30          5        NaN       НЕТ        ДА
# 10              30         30          0        NaN      null      null
# 11              30         30          0        NaN      null      null
# 12              30         30          2        NaN       НЕТ        ДА
# 13              30         30          2        NaN      null      null
# 14              30         30          6        NaN       НЕТ       НЕТ
# 15              30         30          6        NaN       НЕТ       НЕТ
# 16              30         30          4        NaN       НЕТ       НЕТ
# 17              30         30          4        NaN       НЕТ       НЕТ
# 18              30         30         30        NaN       НЕТ       НЕТ
# 19              30         30         30        NaN      null      null
# 20              30         30         30        NaN      null      null
# 21              30         30         30        NaN      null      null
# 22              30         30         30        NaN      null      null
# 23              30         30         30        NaN       НЕТ       НЕТ
# 24              30         30         30        NaN      null      null
# 25              30         30         30        NaN       НЕТ       НЕТ
# 26              30         30         30        NaN       НЕТ       НЕТ
# 27              30         30         30        NaN       НЕТ       НЕТ
# 28              30         30         30        NaN       НЕТ       НЕТ
# 29              30         30         30        NaN      null      null
# ...            ...        ...        ...        ...       ...       ...
# 1996443         30         30          0        NaN      null      null
# 1996444         30         30          4        NaN        ДА        ДА
# 1996445         30         30          1        NaN      null      null
# 1996446         30         30          0        NaN      null      null
# 1996447         30         30          0        NaN      null      null
# 1996448         30         30         30        NaN      null      null
# 1996449         30         30         30        NaN      null      null
# 1996450         30         30          3        NaN      null      null
# 1996451         30         30          3        1.0       НЕТ       НЕТ
# 1996452         30         30          4        NaN       НЕТ        ДА
# 1996453         30         30          4        NaN      null      null
# 1996454         30         30          0        NaN      null      null
# 1996455         30         30          0        NaN       НЕТ       НЕТ
# 1996456         30         30          0        NaN       НЕТ       НЕТ
# 1996457         30         30          0        NaN      null      null
# 1996458         30         30          1        NaN       НЕТ        ДА
# 1996459         30         30          1        NaN      null      null
# 1996460          0          0          0        NaN        ДА        ДА
# 1996461          0         30          0        NaN      null      null
# 1996462          1         30          1        NaN      null      null
# 1996463          1          1          1        NaN        ДА        ДА
# 1996464          1         30          1        NaN      null      null
# 1996465          1         30          1        NaN      null      null
# 1996466          0         30          0        NaN      null      null
# 1996467         30         30          0        NaN      null      null
# 1996468         30         30          5        NaN      null      null
# 1996469         30         30          5        NaN      null      null
# 1996470         30         30          3        NaN      null      null
# 1996471          5         30          4        NaN      null      null
# 1996472         30         30          2        NaN       НЕТ        ДА
#
#            ...                       user_acct_number_hashed  \
# 0          ...                                          None
# 1          ...                                          None
# 2          ...                                          None
# 3          ...                                          None
# 4          ...      ab384e61bdf71c7d28e7f3574ba471da93ae8bcb
# 5          ...      45ac3cab944dbc9ca619063935c55efbb2578f8b
# 6          ...      79d9e7c08fc8a4ab12db612547341c93b8a1cae2
# 7          ...      3f6593c23eda6cd4a39dca74f7f7818577fd10b6
# 8          ...                                          None
# 9          ...      66273fd45f91ebe919493ce04a5632ebf82b42ca
# 10         ...                                          None
# 11         ...                                          None
# 12         ...      2fff03a0efb579bc6b18b57cbe66562b41de410f
# 13         ...                                          None
# 14         ...      e12fbc8f931b1f331bcf1eb9021979287c3370a0
# 15         ...      a56beffc7eb83c260f754f64dd34c7f5a238d958
# 16         ...      edb7679f084004f788ba02d42af22b79f5fd3ddc
# 17         ...      bb8c3f116ab7ba9f763dd2f8fb15ff550a15bf65
# 18         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 19         ...                                          None
# 20         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 21         ...                                          None
# 22         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 23         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 24         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 25         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 26         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 27         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 28         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 29         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# ...        ...                                           ...
# 1996443    ...                                          None
# 1996444    ...      837fcc5a869e0f79a69fab88e1e0ebc438953bd4
# 1996445    ...                                          None
# 1996446    ...                                          None
# 1996447    ...                                          None
# 1996448    ...                                          None
# 1996449    ...                                          None
# 1996450    ...                                          None
# 1996451    ...      f42cb3e9802efd0606a1d446f037ec2fb4c97842
# 1996452    ...      037b733f0dc95d5ab71305883a7c1d18ad244835
# 1996453    ...                                          None
# 1996454    ...                                          None
# 1996455    ...      510926a030b84665e3914214c0f0e80c5748fa47
# 1996456    ...      510926a030b84665e3914214c0f0e80c5748fa47
# 1996457    ...                                          None
# 1996458    ...      510926a030b84665e3914214c0f0e80c5748fa47
# 1996459    ...                                          None
# 1996460    ...      01c324d8d97857d14a69389aabb867da57f2f8db
# 1996461    ...                                          None
# 1996462    ...                                          None
# 1996463    ...      34fb74608a0f8c8d2fbfcef430b9bf04ef254523
# 1996464    ...                                          None
# 1996465    ...                                          None
# 1996466    ...                                          None
# 1996467    ...                                          None
# 1996468    ...                                          None
# 1996469    ...                                          None
# 1996470    ...      f63df74a38668a31d93c90d85ebcb0636feabfa5
# 1996471    ...                                          None
# 1996472    ...      0a8defba0bdc95390964e59656a551e63c285b45
#
#          user_agent_string_hash  browser_plugins_hash  screen_hash  \
# 0                          None                  None         None
# 1                          None                  None         None
# 2                          None                  None         None
# 3                          None                  None         None
# 4                          None                  None         None
# 5                          None                  None         None
# 6                          None                  None         None
# 7                          None                  None         None
# 8                          None                  None         None
# 9                          None                  None         None
# 10                         None                  None         None
# 11                         None                  None         None
# 12                         None                  None         None
# 13                         None                  None         None
# 14                         None                  None         None
# 15                         None                  None         None
# 16                   ee467ea119            1f9c411ec5   ec50032e0a
# 17                   ee467ea119            1f9c411ec5   ec50032e0a
# 18                   d132bdde37            d9790ecce4   2e0fce399d
# 19                   d132bdde37            d9790ecce4   2e0fce399d
# 20                   d132bdde37            d9790ecce4   2e0fce399d
# 21                   d132bdde37            d9790ecce4   2e0fce399d
# 22                   d132bdde37            d9790ecce4   2e0fce399d
# 23                   d132bdde37            d9790ecce4   2e0fce399d
# 24                   d132bdde37            d9790ecce4   2e0fce399d
# 25                   d132bdde37            d9790ecce4   2e0fce399d
# Index(['Unnamed: 0', 'cdf_s_123', 'cdf_s_124', 'cdf_s_127', 'cdf_s_135',
#        'cdf_s_130', 'cdf_s_129', 'cdf_s_134', 'cdf_s_128', 'cdf_s_138',
#        'cdf_s_126', 'cdf_s_133', 'cdf_s_136', 'cdf_s_137', 'cdf_s_140',
#        'cdf_s_178_hashed', 'cdf_s_19', 'cdf_s_20', 'cdf_s_218', 'cdf_s_294',
#        'cdf_s_299', 'amount_original', 'channel_indicator_desc', 'data_i_118',
#        'data_i_119', 'data_i_120', 'data_i_154', 'data_s_65',
#        'event_description', 'event_id', 'event_time', 'ext_acct_number_hashed',
#        'hardwareid', 'short_date', 'user_acct_number_hashed',
#        'user_agent_string_hash', 'browser_plugins_hash', 'screen_hash',
#        'user_id', 'ip_address', 'ip_country', 'ip_region', 'ip_city',
#        'ip_isp'],
#       dtype='object')

# %%
d.drop('Unnamed: 0',axis = 1)
# Out:
#                      cdf_s_123              cdf_s_124  cdf_s_127  cdf_s_135  \
# 0                          NaN                    NaN         30         30
# 1                          NaN                    NaN         30         30
# 2                          NaN                    NaN         30         30
# 3                          NaN                    NaN         30         30
# 4                          NaN                    NaN         30         30
# 5                          NaN                    NaN         30         30
# 6                          NaN                    NaN         30          2
# 7                          NaN                    NaN         30          2
# 8                          NaN                    NaN         30         30
# 9                          NaN                    NaN         30         30
# 10                         NaN                    NaN         30         30
# 11                         NaN                    NaN         30         30
# 12                         NaN                    NaN         30          2
# 13                         NaN                    NaN         30          2
# 14                         NaN                    NaN         30         30
# 15                         NaN                    NaN         30         30
# 16                         NaN                    NaN         30          4
# 17                         NaN                    NaN         30          4
# 18       1994-08-21 00:00:00.0  2017-09-12 00:00:00.0         30          0
# 19                         NaN                    NaN         30          0
# 20                         NaN                    NaN         30          0
# 21                         NaN                    NaN         30          0
# 22                         NaN                    NaN         30          0
# 23                         NaN                    NaN         30          0
# 24                         NaN                    NaN         30          0
# 25       1994-07-10 00:00:00.0  2017-03-17 00:00:00.0         30          0
# 26       1987-05-07 00:00:00.0  2016-10-14 00:00:00.0         30          0
# 27       1989-05-14 00:00:00.0  2016-09-17 00:00:00.0         30          0
# 28       1994-10-21 00:00:00.0  2017-08-10 00:00:00.0         30          0
# 29                         NaN                    NaN         30          0
# ...                        ...                    ...        ...        ...
# 1996443                    NaN                    NaN         30         30
# 1996444  2003-02-19 00:00:00.0  2017-08-31 00:00:00.0         30         30
# 1996445                    NaN                    NaN         30          5
# 1996446                    NaN                    NaN         30         30
# 1996447                    NaN                    NaN         30         30
# 1996448                    NaN                    NaN         30         30
# 1996449                    NaN                    NaN         30         30
# 1996450                    NaN                    NaN         30          0
# 1996451                    NaN                    NaN         30          1
# 1996452                    NaN                    NaN         30          1
# 1996453                    NaN                    NaN         30          1
# 1996454                    NaN                    NaN         30         30
# 1996455  2017-05-24 00:00:00.0  1995-01-07 00:00:00.0         30         30
# 1996456                    NaN                    NaN         30         30
# 1996457                    NaN                    NaN         30         30
# 1996458                    NaN                    NaN         30         30
# 1996459                    NaN                    NaN         30         30
# 1996460                    NaN                    NaN         30          0
# 1996461                    NaN                    NaN         30          0
# 1996462                    NaN                    NaN         30          1
# 1996463                    NaN                    NaN         30          1
# 1996464                    NaN                    NaN         30          1
# 1996465                    NaN                    NaN         30          1
# 1996466                    NaN                    NaN         30          0
# 1996467                    NaN                    NaN         30          0
# 1996468                    NaN                    NaN         30         30
# 1996469                    NaN                    NaN         30         30
# 1996470                    NaN                    NaN         30         30
# 1996471                    NaN                    NaN         30          5
# 1996472                    NaN                    NaN         30         30
#
#          cdf_s_130  cdf_s_129  cdf_s_134  cdf_s_128 cdf_s_138 cdf_s_126  \
# 0               30         30          5        NaN      null      null
# 1               30         30          5        NaN      null      null
# 2               30         30          0        NaN      null      null
# 3               30         30          0        NaN      null      null
# 4               30         30          5        NaN       НЕТ       НЕТ
# 5               30         30          0        NaN       НЕТ        ДА
# 6               30         30          0        NaN       НЕТ        ДА
# 7               30         30          0        NaN       НЕТ        ДА
# 8               30         30          5        NaN      null      null
# 9               30         30          5        NaN       НЕТ        ДА
# 10              30         30          0        NaN      null      null
# 11              30         30          0        NaN      null      null
# 12              30         30          2        NaN       НЕТ        ДА
# 13              30         30          2        NaN      null      null
# 14              30         30          6        NaN       НЕТ       НЕТ
# 15              30         30          6        NaN       НЕТ       НЕТ
# 16              30         30          4        NaN       НЕТ       НЕТ
# 17              30         30          4        NaN       НЕТ       НЕТ
# 18              30         30         30        NaN       НЕТ       НЕТ
# 19              30         30         30        NaN      null      null
# 20              30         30         30        NaN      null      null
# 21              30         30         30        NaN      null      null
# 22              30         30         30        NaN      null      null
# 23              30         30         30        NaN       НЕТ       НЕТ
# 24              30         30         30        NaN      null      null
# 25              30         30         30        NaN       НЕТ       НЕТ
# 26              30         30         30        NaN       НЕТ       НЕТ
# 27              30         30         30        NaN       НЕТ       НЕТ
# 28              30         30         30        NaN       НЕТ       НЕТ
# 29              30         30         30        NaN      null      null
# ...            ...        ...        ...        ...       ...       ...
# 1996443         30         30          0        NaN      null      null
# 1996444         30         30          4        NaN        ДА        ДА
# 1996445         30         30          1        NaN      null      null
# 1996446         30         30          0        NaN      null      null
# 1996447         30         30          0        NaN      null      null
# 1996448         30         30         30        NaN      null      null
# 1996449         30         30         30        NaN      null      null
# 1996450         30         30          3        NaN      null      null
# 1996451         30         30          3        1.0       НЕТ       НЕТ
# 1996452         30         30          4        NaN       НЕТ        ДА
# 1996453         30         30          4        NaN      null      null
# 1996454         30         30          0        NaN      null      null
# 1996455         30         30          0        NaN       НЕТ       НЕТ
# 1996456         30         30          0        NaN       НЕТ       НЕТ
# 1996457         30         30          0        NaN      null      null
# 1996458         30         30          1        NaN       НЕТ        ДА
# 1996459         30         30          1        NaN      null      null
# 1996460          0          0          0        NaN        ДА        ДА
# 1996461          0         30          0        NaN      null      null
# 1996462          1         30          1        NaN      null      null
# 1996463          1          1          1        NaN        ДА        ДА
# 1996464          1         30          1        NaN      null      null
# 1996465          1         30          1        NaN      null      null
# 1996466          0         30          0        NaN      null      null
# 1996467         30         30          0        NaN      null      null
# 1996468         30         30          5        NaN      null      null
# 1996469         30         30          5        NaN      null      null
# 1996470         30         30          3        NaN      null      null
# 1996471          5         30          4        NaN      null      null
# 1996472         30         30          2        NaN       НЕТ        ДА
#
#            ...                       user_acct_number_hashed  \
# 0          ...                                           NaN
# 1          ...                                           NaN
# 2          ...                                           NaN
# 3          ...                                           NaN
# 4          ...      ab384e61bdf71c7d28e7f3574ba471da93ae8bcb
# 5          ...      45ac3cab944dbc9ca619063935c55efbb2578f8b
# 6          ...      79d9e7c08fc8a4ab12db612547341c93b8a1cae2
# 7          ...      3f6593c23eda6cd4a39dca74f7f7818577fd10b6
# 8          ...                                           NaN
# 9          ...      66273fd45f91ebe919493ce04a5632ebf82b42ca
# 10         ...                                           NaN
# 11         ...                                           NaN
# 12         ...      2fff03a0efb579bc6b18b57cbe66562b41de410f
# 13         ...                                           NaN
# 14         ...      e12fbc8f931b1f331bcf1eb9021979287c3370a0
# 15         ...      a56beffc7eb83c260f754f64dd34c7f5a238d958
# 16         ...      edb7679f084004f788ba02d42af22b79f5fd3ddc
# 17         ...      bb8c3f116ab7ba9f763dd2f8fb15ff550a15bf65
# 18         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 19         ...                                           NaN
# 20         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 21         ...                                           NaN
# 22         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 23         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 24         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 25         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 26         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 27         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 28         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# 29         ...      1695fe3ccf53d0a8176b20d8766b5f6e299ef22c
# ...        ...                                           ...
# 1996443    ...                                           NaN
# 1996444    ...      837fcc5a869e0f79a69fab88e1e0ebc438953bd4
# 1996445    ...                                           NaN
# 1996446    ...                                           NaN
# 1996447    ...                                           NaN
# 1996448    ...                                           NaN
# 1996449    ...                                           NaN
# 1996450    ...                                           NaN
# 1996451    ...      f42cb3e9802efd0606a1d446f037ec2fb4c97842
# 1996452    ...      037b733f0dc95d5ab71305883a7c1d18ad244835
# 1996453    ...                                           NaN
# 1996454    ...                                           NaN
# 1996455    ...      510926a030b84665e3914214c0f0e80c5748fa47
# 1996456    ...      510926a030b84665e3914214c0f0e80c5748fa47
# 1996457    ...                                           NaN
# 1996458    ...      510926a030b84665e3914214c0f0e80c5748fa47
# 1996459    ...                                           NaN
# 1996460    ...      01c324d8d97857d14a69389aabb867da57f2f8db
# 1996461    ...                                           NaN
# 1996462    ...                                           NaN
# 1996463    ...      34fb74608a0f8c8d2fbfcef430b9bf04ef254523
# 1996464    ...                                           NaN
# 1996465    ...                                           NaN
# 1996466    ...                                           NaN
# 1996467    ...                                           NaN
# 1996468    ...                                           NaN
# 1996469    ...                                           NaN
# 1996470    ...      f63df74a38668a31d93c90d85ebcb0636feabfa5
# 1996470  MBK13144216              NaN        NaN       NaN               NaN
# 1996471   MBK5658569   109.195.114.23         ru        88         Yaroslavl
# 1996472   VSP5096617    85.140.19.232         ru     empty             empty
#
#             ip_isp
# 0        6095671.0
# 1        6095671.0
# 2        7042071.0
# 3        7042071.0
# 4        2225362.0
# 5        7255229.0
# 6        7042071.0
# 7        7042071.0
# 8        7377135.0
# 9        7377135.0
# 10             NaN
# 11       7320382.0
# 12       7255229.0
# 13       7255229.0
# 14       7255229.0
# 15       7255229.0
# 16       7042071.0
# 17       7042071.0
# 18       8638851.0
# 19       8638851.0
# 20       8638851.0
# 21       8638851.0
# 22       8638851.0
# 23       8638851.0
# 24       8638851.0
# 25       8638851.0
# 26       8638851.0
# 27       8638851.0
# 28       8638851.0
# 29       8638851.0
# ...            ...
# 1996443  7335751.0
# 1996444  7255229.0
# 1996445  7042071.0
# 1996446  4981667.0
# 1996447  4981667.0
# 1996448  7255560.0
# 1996449  7255560.0
# 1996450  6467418.0
# 1996451  6467418.0
# 1996452  7320382.0
# 1996453  7320382.0
# 1996454  7930553.0
# 1996455  7930553.0
# 1996456  7930553.0
# 1996457  7255560.0
# 1996458  7255560.0
# 1996459  7255560.0
# 1996460  7320382.0
# 1996461  7255229.0
# 1996462  7042071.0
# 1996463  7042071.0
# 1996464  6095671.0
# 1996465  6095671.0
# 1996466  7320382.0
# 1996467  7320382.0
# 1996468  7255229.0
# 1996469  7255229.0
# 1996470        NaN
# 1996471  7318189.0
# 1996472  7255229.0
#
# [1996473 rows x 43 columns]

# %%
import scipy
scipy.sparse.csr_matrix(data.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-bac3ad7f5f3b> in <module>()
#       1 import scipy
# ----> 2 scipy.sparse.csr_matrix(data.values)
#
# /home/alex/anaconda3/lib/python3.6/site-packages/scipy/sparse/compressed.py in __init__(self, arg1, shape, dtype, copy)
#      77                         self.format)
#      78             from .coo import coo_matrix
# ---> 79             self._set_self(self.__class__(coo_matrix(arg1, dtype=dtype)))
#      80
#      81         # Read matrix dimensions given, if any
#
# /home/alex/anaconda3/lib/python3.6/site-packages/scipy/sparse/compressed.py in __init__(self, arg1, shape, dtype, copy)
#      30                 arg1 = arg1.copy()
#      31             else:
# ---> 32                 arg1 = arg1.asformat(self.format)
#      33             self._set_self(arg1)
#      34
#
# /home/alex/anaconda3/lib/python3.6/site-packages/scipy/sparse/base.py in asformat(self, format)
#     265             return self
#     266         else:
# --> 267             return getattr(self, 'to' + format)()
#     268
#     269     ###################################################################
#
# /home/alex/anaconda3/lib/python3.6/site-packages/scipy/sparse/coo.py in tocsr(self, copy)
#     332             indptr = np.empty(M + 1, dtype=idx_dtype)
#     333             indices = np.empty_like(col, dtype=idx_dtype)
# --> 334             data = np.empty_like(self.data, dtype=upcast(self.dtype))
#     335
#     336             coo_tocsr(M, N, self.nnz, row, col, self.data,
#
# /home/alex/anaconda3/lib/python3.6/site-packages/scipy/sparse/sputils.py in upcast(*args)
#      49             return t
#      50
# ---> 51     raise TypeError('no supported conversion for types: %r' % (args,))
#      52
#      53
#
# TypeError: no supported conversion for types: (dtype('O'),)
