# %%
import pandas as pd
import numpy as np
import sqlite3
import datetime
import sklearn
import sqlalchemy as sa
from tqdm import tqdm_notebook
import itertools
import pickle
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn import metrics

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, auc

import operator
import gc

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', -1)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %matplotlib inline

# %% [markdown]
# ---

# %% [markdown]
# для обучения берем только данные с 20171029 по 20171128<br>
# для теста с 20171129 по 20171205

# %%
# %%time
# !mkdir -p ../../data/predictions/
train_df = pd.read_feather('../../data/combined_dataset/train_v1.fth')
test_df = pd.read_feather('../../data/combined_dataset/test_v1.fth')
# Out:
# CPU times: user 1.87 s, sys: 3.91 s, total: 5.78 s
# Wall time: 6.08 s

# %%
# %%time
drop_cols = ['event_id', 'user_id', 'short_date', 'event_time']
train_df.drop(columns = drop_cols, inplace = True)
test_df.drop(columns = drop_cols, inplace = True)
# Out:
# CPU times: user 1.15 s, sys: 3.41 s, total: 4.56 s
# Wall time: 4.55 s

# %%
train_df = train_df.loc[train_df['label'].isin([0, 1])].copy()

# %% [markdown]
# параметры для xgboost были подобраны в другом ноутбуке через GridSearch

# %% [raw]
# %%time
# dtrain = xgb.DMatrix(train_df.drop('label', axis = 1), label=train_df['label'], missing=np.NAN)
# dtest = xgb.DMatrix(test_df, missing=np.NAN)

# %%
model = xgb.XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.5,
                          gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=8,
                          min_child_weight=1, missing=None, n_estimators=200,
                          objective='binary:logistic', reg_alpha=8, reg_lambda=1,
                          scale_pos_weight=1, seed=0, silent=True, subsample=0.6, n_jobs=16)

# %%
# %%time
predictor = model.fit(train_df.drop('label', axis = 1), train_df['label'])
# Out:
# CPU times: user 1h 39min 5s, sys: 20.5 s, total: 1h 39min 25s
# Wall time: 8min 31s

# %%
fi = pd.DataFrame({'fname': train_df.drop('label', axis = 1).columns, 'importance': predictor.feature_importances_})

# %%
with pd.option_context('display.max.rows', 200):
    display(fi.sort_values('importance', ascending = False).reset_index().drop('index', axis = 1))
# Out:
#                                     fname  importance
# 0    client_age                            0.093604
# 1    amnt2chnls                            0.052069
# 2    amount                                0.049110
# 3    event_hour                            0.046852
# 4    cumulative_sum_total                  0.045648
# 5    ip_isp                                0.042689
# 6    data_i_154                            0.038726
# 7    client_region                         0.033007
# 8    log_amount                            0.031803
# 9    woe_amnt2chnls                        0.028242
# 10   event_day                             0.025533
# 11   transfer_age_diff                     0.025332
# 12   woe_client_age                        0.020617
# 13   transfer_know_recip_squared           0.020166
# 14   woe_ip_isp                            0.020015
# 15   woe_age_diff                          0.017407
# 16   cdf_s_134                             0.016453
# 17   woe_data_i_154                        0.016403
# 18   woe_amount                            0.015149
# 19   cdf_s_130                             0.013494
# 20   cdf_s_133                             0.013093
# 21   woe_cumulative_sum_total              0.012591
# 22   woe_data_i_120                        0.011487
# 23   woe_log_amount                        0.010936
# 24   cdf_s_135                             0.010484
# 25   cdf_s_127                             0.009832
# 26   woe_cdf_s_133                         0.009531
# 27   data_i_120                            0.008979
# 28   cdf_s_129                             0.008678
# 29   woe_cdf_s_134                         0.008578
# 30   cat_new_prov                          0.008427
# 31   woe_know_recip_power                  0.007625
# 32   op_type                               0.007474
# 33   cat_new_ip                            0.007223
# 34   woe_cdf_s_130                         0.007123
# 35   ATMAPI_30_days_quantile_0.1           0.007023
# 36   woe_cdf_s_135                         0.006973
# 37   woe_cat_new_prov                      0.006922
# 38   woe_op_type                           0.006822
# 39   MBK_30_days_quantile_0.1              0.006421
# 40   recip_card_age                        0.006371
# 41   WEBAPI_30_days_quantile_0.1           0.006321
# 42   is_ru_mobile                          0.005969
# 43   woe_cdf_s_129                         0.005869
# 44   MOBILEAPI_30_days_quantile_0.1        0.005568
# 45   one_region                            0.005267
# 46   event_hour_night                      0.005016
# 47   is_mts                                0.004916
# 48   woe_recip_card_age                    0.004765
# 49   user_id_digit_only                    0.004615
# 50   is_megafon                            0.004314
# 51   woe_data_i_120.1                      0.004264
# 52   ip_contry_ru                          0.004214
# 53   woe_cdf_s_127                         0.004113
# 54   user_id_MBK                           0.004013
# 55   is_tele2                              0.004013
# 56   woe_krp_pow2                          0.003963
# 57   MOBILEAPI_30_days_quantile_0.2        0.003963
# 58   woe_cumulative_sum_total.1            0.003963
# 59   woe_one_region                        0.003863
# 60   woe_cat_new_ip                        0.003762
# 61   ip_contry_is_other                    0.003311
# 62   MBK_30_days_quantile_0.2              0.003060
# 63   amount_original_30_days_quantile_0.1  0.003010
# 64   WEBAPI_30_days_quantile_0.2           0.002960
# 65   know_recip_card_age                   0.002960
# 66   event_day_is_weekend                  0.002709
# 67   amount_original_30_days_quantile_1.0  0.002458
# 68   ATMAPI_30_days_quantile_0.2           0.002408
# 69   ATMAPI_30_days_quantile_0.3           0.001856
# 70   amount_original_30_days_quantile_0.2  0.001806
# 71   MBK_30_days_quantile_0.3              0.001806
# 72   transfer_for_relative                 0.001806
# 73   transfer_recip_age                    0.001806
# 74   amount_original_30_days_quantile_0.9  0.001706
# 75   woe_know_recip_card_age               0.001706
# 76   browser_plugins_hash_notnull          0.001505
# 77   MOBILEAPI_30_days_quantile_0.3        0.001405
# 78   ATMAPI_30_days_quantile_0.4           0.001405
# 79   amount_original_30_days_quantile_0.6  0.001304
# 80   ip_contry_ua                          0.001304
# 81   woe_relative                          0.001254
# 82   MOBILEAPI_30_days_quantile_1.0        0.001204
# 83   amount_original_30_days_quantile_0.3  0.001204
# 84   UFS_30_days_quantile_0.1              0.001204
# 85   amount_original_30_days_quantile_0.8  0.001154
# 86   amount_original_30_days_quantile_0.5  0.001104
# 87   WEBAPI_30_days_quantile_0.3           0.001053
# 88   hardwareid_notnull                    0.001053
# 89   MBK_30_days_quantile_0.9              0.001003
# 90   user_id_VSP                           0.001003
# 91   MBK_30_days_quantile_0.6              0.000953
# 92   user_agent_string_hash_notnull        0.000953
# 93   WEBAPI_30_days_quantile_0.4           0.000903
# 94   MBK_30_days_quantile_1.0              0.000903
# 95   amount_original_30_days_quantile_0.4  0.000853
# 96   amount_original_30_days_quantile_0.7  0.000702
# 97   ATMAPI_30_days_quantile_0.5           0.000702
# 98   WEBAPI_30_days_quantile_0.5           0.000702
# 99   MBK_30_days_quantile_0.4              0.000702
# 100  MOBILEAPI_30_days_quantile_0.4        0.000652
# 101  WEBAPI_30_days_quantile_0.9           0.000602
# 102  MBK_30_days_quantile_0.5              0.000602
# 103  MOBILEAPI_30_days_quantile_0.6        0.000602
# 104  ip_contry_kz                          0.000602
# 105  is_beeline                            0.000602
# 106  MOBILEAPI_30_days_quantile_0.5        0.000552
# 107  MBK_30_days_quantile_0.8              0.000552
# 108  ATMAPI_30_days_quantile_1.0           0.000502
# 109  ATMAPI_30_days_quantile_0.6           0.000502
# 110  UFS_30_days_quantile_0.3              0.000502
# 111  screen_hash_notnull                   0.000502
# 112  MOBILEAPI_30_days_quantile_0.9        0.000502
# 113  MOBILEAPI_30_days_quantile_0.7        0.000451
# 114  UFS_30_days_quantile_0.2              0.000401
# 115  WEBAPI_30_days_quantile_0.6           0.000401
# 116  MOBILEAPI_30_days_quantile_0.8        0.000401
# 117  ATMAPI_30_days_quantile_0.9           0.000301
# 118  WEBAPI_30_days_quantile_0.7           0.000301
# 119  channel_indicator_desc_is_MOBILEAPI   0.000301
# 120  WEBAPI_30_days_quantile_1.0           0.000251
# 121  MBK_30_days_quantile_0.7              0.000251
# 122  ATMAPI_30_days_quantile_0.8           0.000251
# 123  channel_indicator_desc_is_WEBAPI      0.000201
# 124  ATMAPI_30_days_quantile_0.7           0.000150
# 125  ip_contry_is_unknown                  0.000150
# 126  WEBAPI_30_days_quantile_0.8           0.000100
# 127  user_id_CRM                           0.000100
# 128  UFS_30_days_quantile_0.4              0.000100
# 129  UFS_30_days_quantile_0.6              0.000050
# 130  UFS_30_days_quantile_0.9              0.000000
# 131  ip_contry_null                        0.000000
# 132  user_id_IVR                           0.000000
# 133  user_id_other                         0.000000
# 134  channel_indicator_desc_is_ATMAPI      0.000000
# 135  channel_indicator_desc_is_MBK         0.000000
# 136  UFS_30_days_quantile_1.0              0.000000
# 137  UFS_30_days_quantile_0.7              0.000000
# 138  UFS_30_days_quantile_0.8              0.000000
# 139  UFS_30_days_quantile_0.5              0.000000
# 140  channel_indicator_desc_is_other       0.000000
# 141  ip_contry_br                          0.000000
# 142  event_hour_workhour                   0.000000
# 143  event_hour_evening                    0.000000
# 144  client_age_isnull                     0.000000
# 145  client_region_len                     0.000000
# 146  channel_op                            0.000000
# 147  ip_contry_th                          0.000000
# 148  ip_contry_tr                          0.000000

# %% [markdown]
# some sanity checks

# %%
train_proba = predictor.predict_proba(train_df.drop('label', axis = 1))

# %%
y_train = [1 if x == 1 else 0 for x in train_df['label']]
preds = train_proba[:, 1]

print(f'Обычный ROC-AUC: {roc_auc_score(y_train, preds)}')
average_precision = average_precision_score(y_train, preds)
precision, recall, thresholds = precision_recall_curve(y_train, preds)

plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))
plt.show()

print(f'PR-curve AUC {metrics.auc(recall, precision)}')
# Out:
# Обычный ROC-AUC: 0.984947000484716
# PR-curve AUC 0.5730626955234419

# %% [markdown]
# теперь собственно делаем предсказания

# %%
set(train_df.drop('label', axis = 1).columns) - set(test_df.columns)
# Out:
# set()

# %%
test_proba = predictor.predict_proba(test_df[train_df.drop('label', axis = 1).columns.values])[:, 1]

# %%
test_df.columns.tolist()
# Out:
# ['amount',
#  'client_age',
#  'cat_new_ip',
#  'cat_new_prov',
#  'channel_op',
#  'op_type',
#  'cumulative_sum_total',
#  'data_i_120',
#  'data_i_154',
#  'cdf_s_127',
#  'cdf_s_129',
#  'cdf_s_130',
#  'cdf_s_133',
#  'cdf_s_134',
#  'cdf_s_135',
#  'know_recip_card_age',
#  'recip_card_age',
#  'one_region',
#  'log_amount',
#  'ip_isp',
#  'amnt2chnls',
#  'is_mts',
#  'is_beeline',
#  'is_megafon',
#  'is_tele2',
#  'is_ru_mobile',
#  'ip_contry_ru',
#  'ip_contry_kz',
#  'ip_contry_ua',
#  'ip_contry_br',
#  'ip_contry_tr',
#  'ip_contry_th',
#  'ip_contry_null',
#  'ip_contry_is_unknown',
#  'ip_contry_is_other',
#  'hardwareid_notnull',
#  'user_agent_string_hash_notnull',
#  'browser_plugins_hash_notnull',
#  'screen_hash_notnull',
#  'user_id_MBK',
#  'user_id_VSP',
#  'user_id_CRM',
#  'user_id_IVR',
#  'user_id_other',
#  'user_id_digit_only',
#  'channel_indicator_desc_is_MOBILEAPI',
#  'channel_indicator_desc_is_WEBAPI',
#  'channel_indicator_desc_is_ATMAPI',
#  'channel_indicator_desc_is_MBK',
#  'channel_indicator_desc_is_other',
#  'event_hour',
#  'event_hour_night',
#  'event_hour_workhour',
#  'event_hour_evening',
#  'event_day',
#  'event_day_is_weekend',
#  'client_age_isnull',
#  'transfer_recip_age',
#  'transfer_age_diff',
#  'transfer_for_relative',
#  'transfer_know_recip_squared',
#  'client_region_len',
#  'client_region',
#  'woe_data_i_154',
#  'woe_ip_isp',
#  'woe_amnt2chnls',
#  'woe_cat_new_ip',
#  'woe_cat_new_prov',
#  'woe_op_type',
#  'woe_relative',
#  'woe_cdf_s_127',
#  'woe_cdf_s_135',
#  'woe_cdf_s_130',
#  'woe_cdf_s_129',
#  'woe_cdf_s_134',
#  'woe_cdf_s_133',
#  'woe_know_recip_card_age',
#  'woe_one_region',
#  'woe_amount',
#  'woe_client_age',
#  'woe_age_diff',
#  'woe_cumulative_sum_total',
#  'woe_cumulative_sum_total.1',
#  'woe_data_i_120',
#  'woe_know_recip_power',
#  'woe_data_i_120.1',
#  'woe_recip_card_age',
#  'woe_krp_pow2',
#  'woe_log_amount',
#  'amount_original_30_days_quantile_0.1',
#  'amount_original_30_days_quantile_0.2',
#  'amount_original_30_days_quantile_0.3',
#  'amount_original_30_days_quantile_0.4',
#  'amount_original_30_days_quantile_0.5',
#  'amount_original_30_days_quantile_0.6',
#  'amount_original_30_days_quantile_0.7',
#  'amount_original_30_days_quantile_0.8',
#  'amount_original_30_days_quantile_0.9',
#  'amount_original_30_days_quantile_1.0',
#  'ATMAPI_30_days_quantile_0.1',
#  'ATMAPI_30_days_quantile_0.2',
#  'ATMAPI_30_days_quantile_0.3',
#  'ATMAPI_30_days_quantile_0.4',
#  'ATMAPI_30_days_quantile_0.5',
#  'ATMAPI_30_days_quantile_0.6',
#  'ATMAPI_30_days_quantile_0.7',
#  'ATMAPI_30_days_quantile_0.8',
#  'ATMAPI_30_days_quantile_0.9',
#  'ATMAPI_30_days_quantile_1.0',
#  'WEBAPI_30_days_quantile_0.1',
#  'WEBAPI_30_days_quantile_0.2',
#  'WEBAPI_30_days_quantile_0.3',
#  'WEBAPI_30_days_quantile_0.4',
#  'WEBAPI_30_days_quantile_0.5',
#  'WEBAPI_30_days_quantile_0.6',
#  'WEBAPI_30_days_quantile_0.7',
#  'WEBAPI_30_days_quantile_0.8',
#  'WEBAPI_30_days_quantile_0.9',
#  'WEBAPI_30_days_quantile_1.0',
#  'MBK_30_days_quantile_0.1',
#  'MBK_30_days_quantile_0.2',
#  'MBK_30_days_quantile_0.3',
#  'MBK_30_days_quantile_0.4',
#  'MBK_30_days_quantile_0.5',
#  'MBK_30_days_quantile_0.6',
#  'MBK_30_days_quantile_0.7',
#  'MBK_30_days_quantile_0.8',
#  'MBK_30_days_quantile_0.9',
#  'MBK_30_days_quantile_1.0',
#  'UFS_30_days_quantile_0.1',
#  'UFS_30_days_quantile_0.2',
#  'UFS_30_days_quantile_0.3',
#  'UFS_30_days_quantile_0.4',
#  'UFS_30_days_quantile_0.5',
#  'UFS_30_days_quantile_0.6',
#  'UFS_30_days_quantile_0.7',
#  'UFS_30_days_quantile_0.8',
#  'UFS_30_days_quantile_0.9',
#  'UFS_30_days_quantile_1.0',
#  'MOBILEAPI_30_days_quantile_0.1',
#  'MOBILEAPI_30_days_quantile_0.2',
#  'MOBILEAPI_30_days_quantile_0.3',
#  'MOBILEAPI_30_days_quantile_0.4',
#  'MOBILEAPI_30_days_quantile_0.5',
#  'MOBILEAPI_30_days_quantile_0.6',
#  'MOBILEAPI_30_days_quantile_0.7',
#  'MOBILEAPI_30_days_quantile_0.8',
#  'MOBILEAPI_30_days_quantile_0.9',
#  'MOBILEAPI_30_days_quantile_1.0']

# %%
test_df_raw = pd.read_feather('../../data/combined_dataset/test_v1.fth')

# %%
final = test_df_raw[['event_id']].copy()
final['label_1_prob'] = test_proba

# %%
final.head(5)
# Out:
#                          event_id  label_1_prob
# 0  e264-:4fbd8d52061:1c81f046_TRX  0.055129
# 1  54e7:e19e2b52061:3cbd98c1-_TRX  0.028082
# 2  7581-:454f5d52061:e838eec1_TRX  0.038442
# 3  5ec-:763a2f62061:7ecf1c37_TRX   0.035923
# 4  cd72:c03d2b52061:d95998d3_TRX   0.049398

# %%
final.shape[0]
# Out:
# 696842

# %%
final['label_1_prob'].hist(bins = 100)

# %%
final.to_csv('../../data/predictions/test_prediction_team1.csv', index = None)
