# %%
import pandas as pd

# %%
df = pd.read_feather('../../data/raw_splits/train/chunk_0.fth')

# %%
pd.options.display.max_columns = 200

# %%
df.columns
# Out:
# Index(['cdf_s_123', 'cdf_s_124', 'cdf_s_127', 'cdf_s_135', 'cdf_s_130',
#        'cdf_s_129', 'cdf_s_134', 'cdf_s_128', 'cdf_s_138', 'cdf_s_126',
#        'cdf_s_133', 'cdf_s_136', 'cdf_s_137', 'cdf_s_140', 'cdf_s_178_hashed',
#        'cdf_s_19', 'cdf_s_20', 'cdf_s_218', 'cdf_s_294', 'cdf_s_299',
#        'amount_original', 'channel_indicator_desc', 'custom_mark',
#        'data_i_118', 'data_i_119', 'data_i_120', 'data_i_154', 'data_s_65',
#        'event_description', 'event_id', 'event_time', 'ext_acct_number_hashed',
#        'hardwareid', 'short_date', 'user_acct_number_hashed',
#        'user_agent_string_hash', 'browser_plugins_hash', 'screen_hash',
#        'user_id', 'ip_address', 'ip_country', 'ip_region', 'ip_city',
#        'ip_isp'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   cdf_s_123 cdf_s_124 cdf_s_127 cdf_s_135 cdf_s_130 cdf_s_129 cdf_s_134  \
# 0       NaT       NaT      null      null      null      null      null
# 1       NaT       NaT      null      null      null      null         4
# 2       NaT       NaT      null      null      null      null         6
# 3       NaT       NaT      null      null      null      null      null
# 4       NaT       NaT      null      null      null      null         6
#
#   cdf_s_128 cdf_s_138 cdf_s_126 cdf_s_133 cdf_s_136 cdf_s_137 cdf_s_140  \
# 0      null       НЕТ        ДА         1      null   1000000   1000000
# 1      null      null      null      null      null      null      null
# 2      null       НЕТ        ДА      null      null      null      null
# 3      null      null      null      null      null      null      null
# 4      null       НЕТ        ДА         4      null   1820000   1820000
#
#   cdf_s_178_hashed   cdf_s_19 cdf_s_20 cdf_s_218 cdf_s_294 cdf_s_299  \
# ...

# %%
df['screen_hash'].value_counts()
# Out:
# null          1285982
# b9236421dc      16189
# 2e0fce399d      10691
# b93864e824       4758
# f86c148285       4539
# f68045b6d5       4299
# a0e4def3e5       2158
# 0fed90afae       2154
# 018ff4a686       2088
# 0c70666750       2015
# 849bf84b1d       1944
# f170dfa6c1       1589
# 7c7408ecee       1425
# a1f354ea83       1349
# ec50032e0a       1324
# 59b6ce3626       1005
# e97d0dc270        917
# d6d4d02950        889
# d82521a1f4        675
# 9e8f77b462        635
# 8dc09e46eb        618
# 4bb569ccae        579
# c71844eba0        537
# 1dfaa322e5        522
# 944b43df83        512
# d51d1b4261        447
# ef00af210e        447
# 3cc8296889        403
# 370410ace7        398
# d2a747f552        398
#                ...
# dc096caab0          1
# a694ab0643          1
# 4c1488c1dd          1
# 4dce99d300          1
# a0d0297f8a          1
# 208abe1cb5          1
# 570e87523a          1
# 19adabb785          1
# 35127909a4          1
# 0d1a4ac4ac          1
# ...

# %%
df['ip_region'].value_counts()
# Out:
# 48       293068
# null     222162
# 66        86317
# empty     72544
# 38        70378
# 65        56215
# 61        42206
# 71        37920
# 73        34342
# 53        32593
# 47        23792
# 30        22692
# 59        21688
# 08        21517
# 20        17572
# 13        16417
# 67        15548
# 70        15145
# 51        15024
# 54        13762
# 91        13110
# 90        12836
# 86        11711
# 78        10343
# 29         8553
# 84         8073
# 16         7869
# 32         7052
# 75         7023
# 80         6489
#           ...
# H9           20
# F4           18
# 18           17
# NJ           15
# B6           14
# B5           13
# X5           11
# B9           10
# 36            9
# C4            6
# MN            5
# E3            5
# G3            5
# HI            5
# WV            4
# F9            4
# NV            4
# GA            3
# A2            3
# M8            2
# J2            2
# DE            2
# UT            2
# L7            2
# ...

# %%
df['ip_city'].value_counts()
# Out:
# Moscow                  292596
# null                    222162
# empty                   135435
# Saint Petersburg         85634
# Samara                   48917
# Krasnodar                42894
# Novosibirsk              32046
# Rostov-on-don            31566
# Kazan                    29638
# Yekaterinburg            21222
# Ufa                      18780
# Omsk                     13550
# Ekaterinburg             13512
# Saratov                  13232
# Vladivostok              12204
# Khabarovsk               11977
# Nizhniy Novgorod         11963
# Voronezh                 11546
# Stavropol                10916
# Irkutsk                  10438
# Tyumen                    9478
# Perm                      8171
# Chelyabinsk               7218
# Togliatti                 6681
# Volgograd                 6482
# Izhevsk                   6232
# Rostov-na-donu            5496
# Ulyanovsk                 5394
# Sochi                     5254
# Barnaul                   4820
# ...

# %%
df['ip_country'].value_counts()
# Out:
# ru      1128178
# null     220161
# kz         4612
# th         2678
# ua         1806
# tr         1340
# ++         1163
# ??          838
# eu          694
# cn          665
# us          600
# by          571
# cy          485
# es          436
# ca          389
# no          325
# it          284
# am          274
# ae          266
# gb          259
# fr          220
# nl          214
# kg          207
# hk          204
# gr          198
# de          183
# cz          180
# ge          169
# az          162
# id          146
#          ...
# fo           32
# ma           29
# be           28
# ch           26
# gu           25
# lt           23
# rs           20
# ee           20
# hr           19
# vn           18
# au           18
# mu           16
# dk           16
# mc           16
# lu           14
# lb           11
# jp           10
# se            9
# lk            9
# mn            8
# za            8
# cl            6
# sn            5
# bs            4
# ...

# %%
import whois

# %%
dir(whois)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NICClient',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
# ...

# %%
whois.whois('31.173.86.8')
# Out:
# {'address': None,
#  'city': None,
#  'country': None,
#  'creation_date': None,
#  'dnssec': None,
#  'domain_name': None,
#  'emails': ['hostmaster@ripe.net',
#   'abuse@ripe.net',
#   "'abuse-mailbox@megafon.ru",
#   'abuse-mailbox@megafon.ru',
#   'gnocwest_tr@megafon.ru',
#   'gnoceast_backbone@megafon.ru'],
#  'expiration_date': None,
#  'name': None,
#  'name_servers': None,
#  'org': None,
#  'referral_url': None,
#  'registrar': None,
#  'state': None,
#  'status': 'ASSIGNED PA',
#  'updated_date': None,
#  'whois_server': None,
#  'zipcode': None}
